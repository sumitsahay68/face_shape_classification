# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download sumitsahay/preprocessedv2faceshapedataset
# Out:
# Downloading preprocessedv2faceshapedataset.zip to /content
#  88% 65.0M/73.9M [00:00<00:00, 133MB/s]
# 100% 73.9M/73.9M [00:00<00:00, 119MB/s]

# %%
! unzip /content/preprocessedv2faceshapedataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: faceshape_bw/training_set/Square/square (992).jpg
#   inflating: faceshape_bw/training_set/Square/square (993).jpg
#   inflating: faceshape_bw/training_set/Square/square (994).jpg
#   inflating: faceshape_bw/training_set/Square/square (995).jpg
#   inflating: faceshape_bw/training_set/Square/square (996).jpg
#   inflating: faceshape_bw/training_set/Square/square (997).jpg
#   inflating: faceshape_bw/training_set/Square/square (998).jpg
#   inflating: faceshape_bw/training_set/Square/square (999).jpg
#   inflating: training_set/testing_set/Heart/heart (101).jpg
#   inflating: training_set/testing_set/Heart/heart (102).jpg
#   inflating: training_set/testing_set/Heart/heart (123).jpg
#   inflating: training_set/testing_set/Heart/heart (13).jpg
#   inflating: training_set/testing_set/Heart/heart (135).jpg
#   inflating: training_set/testing_set/Heart/heart (136).jpg
#   inflating: training_set/testing_set/Heart/heart (137).jpg
#   inflating: training_set/testing_set/Heart/heart (138).jpg
#   inflating: training_set/testing_set/Heart/heart (139).jpg
#   inflating: training_set/testing_set/Heart/heart (140).jpg
#   inflating: training_set/testing_set/Heart/heart (141).jpg
#   inflating: training_set/testing_set/Heart/heart (156).jpg
#   inflating: training_set/testing_set/Heart/heart (161).jpg
#   inflating: training_set/testing_set/Heart/heart (163).jpg
#   inflating: training_set/testing_set/Heart/heart (189).jpg
#   inflating: training_set/testing_set/Heart/heart (192).jpg
#   inflating: training_set/testing_set/Heart/heart (194).jpg
#   inflating: training_set/testing_set/Heart/heart (196).jpg
#   inflating: training_set/testing_set/Heart/heart (197).jpg
#   inflating: training_set/testing_set/Heart/heart (200).jpg
#   inflating: training_set/testing_set/Heart/heart (203).jpg
#   inflating: training_set/testing_set/Heart/heart (204).jpg
#   inflating: training_set/testing_set/Heart/heart (223).jpg
#   inflating: training_set/testing_set/Heart/heart (224).jpg
#   inflating: training_set/testing_set/Heart/heart (225).jpg
#   inflating: training_set/testing_set/Heart/heart (226).jpg
#   inflating: training_set/testing_set/Heart/heart (227).jpg
#   inflating: training_set/testing_set/Heart/heart (228).jpg
#   inflating: training_set/testing_set/Heart/heart (229).jpg
#   inflating: training_set/testing_set/Heart/heart (230).jpg
#   inflating: training_set/testing_set/Heart/heart (233).jpg
#   inflating: training_set/testing_set/Heart/heart (234).jpg
#   inflating: training_set/testing_set/Heart/heart (235).jpg
#   inflating: training_set/testing_set/Heart/heart (236).jpg
#   inflating: training_set/testing_set/Heart/heart (237).jpg
#   inflating: training_set/testing_set/Heart/heart (238).jpg
#   inflating: training_set/testing_set/Heart/heart (239).jpg
#   inflating: training_set/testing_set/Heart/heart (240).jpg
#   inflating: training_set/testing_set/Heart/heart (249).jpg
#   inflating: training_set/testing_set/Heart/heart (260).jpg
#   inflating: training_set/testing_set/Heart/heart (271).jpg
#   inflating: training_set/testing_set/Heart/heart (282).jpg
#   inflating: training_set/testing_set/Heart/heart (283).jpg
#   inflating: training_set/testing_set/Heart/heart (291).jpg
#   inflating: training_set/testing_set/Heart/heart (294).jpg
#   inflating: training_set/testing_set/Heart/heart (3).jpg
#   inflating: training_set/testing_set/Heart/heart (303).jpg
#   inflating: training_set/testing_set/Heart/heart (313).jpg
#   inflating: training_set/testing_set/Heart/heart (323).jpg
#   inflating: training_set/testing_set/Heart/heart (326).jpg
#   inflating: training_set/testing_set/Heart/heart (333).jpg
#   inflating: training_set/testing_set/Heart/heart (334).jpg
#   inflating: training_set/testing_set/Heart/heart (336).jpg
#   inflating: training_set/testing_set/Heart/heart (341).jpg
#   inflating: training_set/testing_set/Heart/heart (343).jpg
#   inflating: training_set/testing_set/Heart/heart (344).jpg
#   inflating: training_set/testing_set/Heart/heart (354).jpg
#   inflating: training_set/testing_set/Heart/heart (358).jpg
#   inflating: training_set/testing_set/Heart/heart (362).jpg
#   inflating: training_set/testing_set/Heart/heart (364).jpg
#   inflating: training_set/testing_set/Heart/heart (365).jpg
#   inflating: training_set/testing_set/Heart/heart (37).jpg
#   inflating: training_set/testing_set/Heart/heart (375).jpg
#   inflating: training_set/testing_set/Heart/heart (377).jpg
#   inflating: training_set/testing_set/Heart/heart (379).jpg
#   inflating: training_set/testing_set/Heart/heart (381).jpg
#   inflating: training_set/testing_set/Heart/heart (39).jpg
#   inflating: training_set/testing_set/Heart/heart (395).jpg
#   inflating: training_set/testing_set/Heart/heart (404).jpg
#   inflating: training_set/testing_set/Heart/heart (413).jpg
#   inflating: training_set/testing_set/Heart/heart (414).jpg
#   inflating: training_set/testing_set/Heart/heart (415).jpg
#   inflating: training_set/testing_set/Heart/heart (416).jpg
#   inflating: training_set/testing_set/Heart/heart (417).jpg
#   inflating: training_set/testing_set/Heart/heart (418).jpg
#   inflating: training_set/testing_set/Heart/heart (419).jpg
#   inflating: training_set/testing_set/Heart/heart (420).jpg
#   inflating: training_set/testing_set/Heart/heart (421).jpg
#   inflating: training_set/testing_set/Heart/heart (431).jpg
#   inflating: training_set/testing_set/Heart/heart (433).jpg
#   inflating: training_set/testing_set/Heart/heart (436).jpg
#   inflating: training_set/testing_set/Heart/heart (438).jpg
#   inflating: training_set/testing_set/Heart/heart (442).jpg
#   inflating: training_set/testing_set/Heart/heart (445).jpg
#   inflating: training_set/testing_set/Heart/heart (446).jpg
#   inflating: training_set/testing_set/Heart/heart (450).jpg
#   inflating: training_set/testing_set/Heart/heart (452).jpg
#   inflating: training_set/testing_set/Heart/heart (453).jpg
#   inflating: training_set/testing_set/Heart/heart (454).jpg
#   inflating: training_set/testing_set/Heart/heart (455).jpg
#   inflating: training_set/testing_set/Heart/heart (456).jpg
#   inflating: training_set/testing_set/Heart/heart (462).jpg
#   inflating: training_set/testing_set/Heart/heart (465).jpg
#   inflating: training_set/testing_set/Heart/heart (474).jpg
#   inflating: training_set/testing_set/Heart/heart (483).jpg
#   inflating: training_set/testing_set/Heart/heart (485).jpg
#   inflating: training_set/testing_set/Heart/heart (487).jpg
#   inflating: training_set/testing_set/Heart/heart (488).jpg
#   inflating: training_set/testing_set/Heart/heart (491).jpg
#   inflating: training_set/testing_set/Heart/heart (493).jpg
#   inflating: training_set/testing_set/Heart/heart (5).jpg
#   inflating: training_set/testing_set/Heart/heart (505).jpg
#   inflating: training_set/testing_set/Heart/heart (507).jpg
#   inflating: training_set/testing_set/Heart/heart (518).jpg
#   inflating: training_set/testing_set/Heart/heart (522).jpg
#   inflating: training_set/testing_set/Heart/heart (523).jpg
#   inflating: training_set/testing_set/Heart/heart (525).jpg
#   inflating: training_set/testing_set/Heart/heart (535).jpg
#   inflating: training_set/testing_set/Heart/heart (536).jpg
#   inflating: training_set/testing_set/Heart/heart (553).jpg
#   inflating: training_set/testing_set/Heart/heart (576).jpg
#   inflating: training_set/testing_set/Heart/heart (577).jpg
#   inflating: training_set/testing_set/Heart/heart (578).jpg
#   inflating: training_set/testing_set/Heart/heart (579).jpg
#   inflating: training_set/testing_set/Heart/heart (580).jpg
#   inflating: training_set/testing_set/Heart/heart (583).jpg
#   inflating: training_set/testing_set/Heart/heart (592).jpg
#   inflating: training_set/testing_set/Heart/heart (597).jpg
#   inflating: training_set/testing_set/Heart/heart (602).jpg
#   inflating: training_set/testing_set/Heart/heart (603).jpg
#   inflating: training_set/testing_set/Heart/heart (606).jpg
#   inflating: training_set/testing_set/Heart/heart (609).jpg
#   inflating: training_set/testing_set/Heart/heart (612).jpg
#   inflating: training_set/testing_set/Heart/heart (615).jpg
#   inflating: training_set/testing_set/Heart/heart (617).jpg
#   inflating: training_set/testing_set/Heart/heart (624).jpg
#   inflating: training_set/testing_set/Heart/heart (641).jpg
#   inflating: training_set/testing_set/Heart/heart (644).jpg
#   inflating: training_set/testing_set/Heart/heart (647).jpg
#   inflating: training_set/testing_set/Heart/heart (648).jpg
#   inflating: training_set/testing_set/Heart/heart (649).jpg
#   inflating: training_set/testing_set/Heart/heart (650).jpg
#   inflating: training_set/testing_set/Heart/heart (651).jpg
#   inflating: training_set/testing_set/Heart/heart (657).jpg
#   inflating: training_set/testing_set/Heart/heart (658).jpg
#   inflating: training_set/testing_set/Heart/heart (659).jpg
#   inflating: training_set/testing_set/Heart/heart (660).jpg
#   inflating: training_set/testing_set/Heart/heart (661).jpg
#   inflating: training_set/testing_set/Heart/heart (665).jpg
#   inflating: training_set/testing_set/Heart/heart (673).jpg
#   inflating: training_set/testing_set/Heart/heart (674).jpg
#   inflating: training_set/testing_set/Heart/heart (675).jpg
#   inflating: training_set/testing_set/Heart/heart (676).jpg
#   inflating: training_set/testing_set/Heart/heart (683).jpg
#   inflating: training_set/testing_set/Heart/heart (685).jpg
#   inflating: training_set/testing_set/Heart/heart (686).jpg
#   inflating: training_set/testing_set/Heart/heart (691).jpg
#   inflating: training_set/testing_set/Heart/heart (7).jpg
#   inflating: training_set/testing_set/Heart/heart (702).jpg
#   inflating: training_set/testing_set/Heart/heart (703).jpg
#   inflating: training_set/testing_set/Heart/heart (712).jpg
#   inflating: training_set/testing_set/Heart/heart (722).jpg
#   inflating: training_set/testing_set/Heart/heart (724).jpg
#   inflating: training_set/testing_set/Heart/heart (726).jpg
#   inflating: training_set/testing_set/Heart/heart (743).jpg
#   inflating: training_set/testing_set/Heart/heart (757).jpg
#   inflating: training_set/testing_set/Heart/heart (766).jpg
#   inflating: training_set/testing_set/Heart/heart (767).jpg
#   inflating: training_set/testing_set/Heart/heart (768).jpg
#   inflating: training_set/testing_set/Heart/heart (769).jpg
#   inflating: training_set/testing_set/Heart/heart (770).jpg
#   inflating: training_set/testing_set/Heart/heart (776).jpg
#   inflating: training_set/testing_set/Heart/heart (777).jpg
#   inflating: training_set/testing_set/Heart/heart (778).jpg
#   inflating: training_set/testing_set/Heart/heart (779).jpg
#   inflating: training_set/testing_set/Heart/heart (780).jpg
#   inflating: training_set/testing_set/Heart/heart (786).jpg
#   inflating: training_set/testing_set/Heart/heart (787).jpg
#   inflating: training_set/testing_set/Heart/heart (788).jpg
#   inflating: training_set/testing_set/Heart/heart (789).jpg
#   inflating: training_set/testing_set/Heart/heart (790).jpg
#   inflating: training_set/testing_set/Heart/heart (803).jpg
#   inflating: training_set/testing_set/Heart/heart (843).jpg
#   inflating: training_set/testing_set/Heart/heart (851).jpg
#   inflating: training_set/testing_set/Heart/heart (854).jpg
#   inflating: training_set/testing_set/Heart/heart (856).jpg
#   inflating: training_set/testing_set/Heart/heart (864).jpg
#   inflating: training_set/testing_set/Heart/heart (872).jpg
#   inflating: training_set/testing_set/Heart/heart (873).jpg
#   inflating: training_set/testing_set/Heart/heart (892).jpg
#   inflating: training_set/testing_set/Heart/heart (901).jpg
#   inflating: training_set/testing_set/Heart/heart (91).jpg
#   inflating: training_set/testing_set/Heart/heart (910).jpg
#   inflating: training_set/testing_set/Heart/heart (912).jpg
#   inflating: training_set/testing_set/Heart/heart (913).jpg
#   inflating: training_set/testing_set/Heart/heart (918).jpg
#   inflating: training_set/testing_set/Heart/heart (919).jpg
#   inflating: training_set/testing_set/Heart/heart (92).jpg
#   inflating: training_set/testing_set/Heart/heart (920).jpg
#   inflating: training_set/testing_set/Heart/heart (923).jpg
#   inflating: training_set/testing_set/Heart/heart (928).jpg
#   inflating: training_set/testing_set/Heart/heart (929).jpg
#   inflating: training_set/testing_set/Heart/heart (930).jpg
#   inflating: training_set/testing_set/Heart/heart (94).jpg
#   inflating: training_set/testing_set/Heart/heart (942).jpg
#   inflating: training_set/testing_set/Heart/heart (971).jpg
#   inflating: training_set/testing_set/Heart/heart (973).jpg
#   inflating: training_set/testing_set/Heart/heart (975).jpg
#   inflating: training_set/testing_set/Heart/heart (986).jpg
#   inflating: training_set/testing_set/Heart/heart (995).jpg
#   inflating: training_set/testing_set/Oblong/oblong (10).jpg
#   inflating: training_set/testing_set/Oblong/oblong (106).jpg
#   inflating: training_set/testing_set/Oblong/oblong (107).jpg
#   inflating: training_set/testing_set/Oblong/oblong (11).jpg
#   inflating: training_set/testing_set/Oblong/oblong (13).jpg
#   inflating: training_set/testing_set/Oblong/oblong (139).jpg
#   inflating: training_set/testing_set/Oblong/oblong (14).jpg
#   inflating: training_set/testing_set/Oblong/oblong (143).jpg
#   inflating: training_set/testing_set/Oblong/oblong (144).jpg
#   inflating: training_set/testing_set/Oblong/oblong (146).jpg
#   inflating: training_set/testing_set/Oblong/oblong (147).jpg
#   inflating: training_set/testing_set/Oblong/oblong (148).jpg
#   inflating: training_set/testing_set/Oblong/oblong (149).jpg
#   inflating: training_set/testing_set/Oblong/oblong (15).jpg
#   inflating: training_set/testing_set/Oblong/oblong (150).jpg
#   inflating: training_set/testing_set/Oblong/oblong (151).jpg
#   inflating: training_set/testing_set/Oblong/oblong (152).jpg
#   inflating: training_set/testing_set/Oblong/oblong (154).jpg
#   inflating: training_set/testing_set/Oblong/oblong (155).jpg
#   inflating: training_set/testing_set/Oblong/oblong (156).jpg
#   inflating: training_set/testing_set/Oblong/oblong (157).jpg
#   inflating: training_set/testing_set/Oblong/oblong (158).jpg
#   inflating: training_set/testing_set/Oblong/oblong (179).jpg
#   inflating: training_set/testing_set/Oblong/oblong (181).jpg
#   inflating: training_set/testing_set/Oblong/oblong (191).jpg
#   inflating: training_set/testing_set/Oblong/oblong (192).jpg
#   inflating: training_set/testing_set/Oblong/oblong (193).jpg
#   inflating: training_set/testing_set/Oblong/oblong (197).jpg
#   inflating: training_set/testing_set/Oblong/oblong (205).jpg
#   inflating: training_set/testing_set/Oblong/oblong (21).jpg
#   inflating: training_set/testing_set/Oblong/oblong (216).jpg
#   inflating: training_set/testing_set/Oblong/oblong (217).jpg
#   inflating: training_set/testing_set/Oblong/oblong (22).jpg
#   inflating: training_set/testing_set/Oblong/oblong (242).jpg
#   inflating: training_set/testing_set/Oblong/oblong (256).jpg
#   inflating: training_set/testing_set/Oblong/oblong (26).jpg
#   inflating: training_set/testing_set/Oblong/oblong (272).jpg
#   inflating: training_set/testing_set/Oblong/oblong (278).jpg
#   inflating: training_set/testing_set/Oblong/oblong (280).jpg
#   inflating: training_set/testing_set/Oblong/oblong (307).jpg
#   inflating: training_set/testing_set/Oblong/oblong (313).jpg
#   inflating: training_set/testing_set/Oblong/oblong (314).jpg
#   inflating: training_set/testing_set/Oblong/oblong (315).jpg
#   inflating: training_set/testing_set/Oblong/oblong (316).jpg
#   inflating: training_set/testing_set/Oblong/oblong (317).jpg
#   inflating: training_set/testing_set/Oblong/oblong (318).jpg
#   inflating: training_set/testing_set/Oblong/oblong (319).jpg
#   inflating: training_set/testing_set/Oblong/oblong (320).jpg
#   inflating: training_set/testing_set/Oblong/oblong (321).jpg
#   inflating: training_set/testing_set/Oblong/oblong (322).jpg
#   inflating: training_set/testing_set/Oblong/oblong (323).jpg
#   inflating: training_set/testing_set/Oblong/oblong (324).jpg
#   inflating: training_set/testing_set/Oblong/oblong (325).jpg
#   inflating: training_set/testing_set/Oblong/oblong (326).jpg
#   inflating: training_set/testing_set/Oblong/oblong (327).jpg
#   inflating: training_set/testing_set/Oblong/oblong (329).jpg
#   inflating: training_set/testing_set/Oblong/oblong (335).jpg
#   inflating: training_set/testing_set/Oblong/oblong (337).jpg
#   inflating: training_set/testing_set/Oblong/oblong (339).jpg
#   inflating: training_set/testing_set/Oblong/oblong (34).jpg
#   inflating: training_set/testing_set/Oblong/oblong (356).jpg
#   inflating: training_set/testing_set/Oblong/oblong (365).jpg
#   inflating: training_set/testing_set/Oblong/oblong (381).jpg
#   inflating: training_set/testing_set/Oblong/oblong (383).jpg
#   inflating: training_set/testing_set/Oblong/oblong (408).jpg
#   inflating: training_set/testing_set/Oblong/oblong (439).jpg
#   inflating: training_set/testing_set/Oblong/oblong (447).jpg
#   inflating: training_set/testing_set/Oblong/oblong (461).jpg
#   inflating: training_set/testing_set/Oblong/oblong (471).jpg
#   inflating: training_set/testing_set/Oblong/oblong (477).jpg
#   inflating: training_set/testing_set/Oblong/oblong (494).jpg
#   inflating: training_set/testing_set/Oblong/oblong (495).jpg
#   inflating: training_set/testing_set/Oblong/oblong (496).jpg
#   inflating: training_set/testing_set/Oblong/oblong (503).jpg
#   inflating: training_set/testing_set/Oblong/oblong (508).jpg
#   inflating: training_set/testing_set/Oblong/oblong (509).jpg
#   inflating: training_set/testing_set/Oblong/oblong (516).jpg
#   inflating: training_set/testing_set/Oblong/oblong (521).jpg
#   inflating: training_set/testing_set/Oblong/oblong (530).jpg
#   inflating: training_set/testing_set/Oblong/oblong (547).jpg
#   inflating: training_set/testing_set/Oblong/oblong (548).jpg
#   inflating: training_set/testing_set/Oblong/oblong (549).jpg
#   inflating: training_set/testing_set/Oblong/oblong (55).jpg
#   inflating: training_set/testing_set/Oblong/oblong (550).jpg
#   inflating: training_set/testing_set/Oblong/oblong (551).jpg
#   inflating: training_set/testing_set/Oblong/oblong (552).jpg
#   inflating: training_set/testing_set/Oblong/oblong (553).jpg
#   inflating: training_set/testing_set/Oblong/oblong (554).jpg
#   inflating: training_set/testing_set/Oblong/oblong (555).jpg
#   inflating: training_set/testing_set/Oblong/oblong (556).jpg
#   inflating: training_set/testing_set/Oblong/oblong (557).jpg
#   inflating: training_set/testing_set/Oblong/oblong (558).jpg
#   inflating: training_set/testing_set/Oblong/oblong (559).jpg
#   inflating: training_set/testing_set/Oblong/oblong (560).jpg
#   inflating: training_set/testing_set/Oblong/oblong (563).jpg
#   inflating: training_set/testing_set/Oblong/oblong (576).jpg
#   inflating: training_set/testing_set/Oblong/oblong (583).jpg
#   inflating: training_set/testing_set/Oblong/oblong (6).jpg
#   inflating: training_set/testing_set/Oblong/oblong (604).jpg
#   inflating: training_set/testing_set/Oblong/oblong (62).jpg
#   inflating: training_set/testing_set/Oblong/oblong (622).jpg
#   inflating: training_set/testing_set/Oblong/oblong (640).jpg
#   inflating: training_set/testing_set/Oblong/oblong (662).jpg
#   inflating: training_set/testing_set/Oblong/oblong (664).jpg
#   inflating: training_set/testing_set/Oblong/oblong (675).jpg
#   inflating: training_set/testing_set/Oblong/oblong (676).jpg
#   inflating: training_set/testing_set/Oblong/oblong (677).jpg
#   inflating: training_set/testing_set/Oblong/oblong (678).jpg
#   inflating: training_set/testing_set/Oblong/oblong (679).jpg
#   inflating: training_set/testing_set/Oblong/oblong (680).jpg
#   inflating: training_set/testing_set/Oblong/oblong (681).jpg
#   inflating: training_set/testing_set/Oblong/oblong (682).jpg
#   inflating: training_set/testing_set/Oblong/oblong (683).jpg
#   inflating: training_set/testing_set/Oblong/oblong (684).jpg
#   inflating: training_set/testing_set/Oblong/oblong (685).jpg
#   inflating: training_set/testing_set/Oblong/oblong (686).jpg
#   inflating: training_set/testing_set/Oblong/oblong (687).jpg
#   inflating: training_set/testing_set/Oblong/oblong (688).jpg
#   inflating: training_set/testing_set/Oblong/oblong (691).jpg
#   inflating: training_set/testing_set/Oblong/oblong (692).jpg
#   inflating: training_set/testing_set/Oblong/oblong (694).jpg
#   inflating: training_set/testing_set/Oblong/oblong (695).jpg
#   inflating: training_set/testing_set/Oblong/oblong (697).jpg
#   inflating: training_set/testing_set/Oblong/oblong (698).jpg
#   inflating: training_set/testing_set/Oblong/oblong (699).jpg
#   inflating: training_set/testing_set/Oblong/oblong (7).jpg
#   inflating: training_set/testing_set/Oblong/oblong (700).jpg
#   inflating: training_set/testing_set/Oblong/oblong (701).jpg
#   inflating: training_set/testing_set/Oblong/oblong (702).jpg
#   inflating: training_set/testing_set/Oblong/oblong (703).jpg
#   inflating: training_set/testing_set/Oblong/oblong (704).jpg
#   inflating: training_set/testing_set/Oblong/oblong (705).jpg
#   inflating: training_set/testing_set/Oblong/oblong (706).jpg
#   inflating: training_set/testing_set/Oblong/oblong (707).jpg
#   inflating: training_set/testing_set/Oblong/oblong (708).jpg
#   inflating: training_set/testing_set/Oblong/oblong (710).jpg
#   inflating: training_set/testing_set/Oblong/oblong (734).jpg
#   inflating: training_set/testing_set/Oblong/oblong (8).jpg
#   inflating: training_set/testing_set/Oblong/oblong (802).jpg
#   inflating: training_set/testing_set/Oblong/oblong (81).jpg
#   inflating: training_set/testing_set/Oblong/oblong (83).jpg
#   inflating: training_set/testing_set/Oblong/oblong (834).jpg
#   inflating: training_set/testing_set/Oblong/oblong (857).jpg
#   inflating: training_set/testing_set/Oblong/oblong (873).jpg
#   inflating: training_set/testing_set/Oblong/oblong (875).jpg
#   inflating: training_set/testing_set/Oblong/oblong (877).jpg
#   inflating: training_set/testing_set/Oblong/oblong (878).jpg
#   inflating: training_set/testing_set/Oblong/oblong (879).jpg
#   inflating: training_set/testing_set/Oblong/oblong (881).jpg
#   inflating: training_set/testing_set/Oblong/oblong (882).jpg
#   inflating: training_set/testing_set/Oblong/oblong (884).jpg
#   inflating: training_set/testing_set/Oblong/oblong (885).jpg
#   inflating: training_set/testing_set/Oblong/oblong (886).jpg
#   inflating: training_set/testing_set/Oblong/oblong (887).jpg
#   inflating: training_set/testing_set/Oblong/oblong (888).jpg
#   inflating: training_set/testing_set/Oblong/oblong (889).jpg
#   inflating: training_set/testing_set/Oblong/oblong (890).jpg
#   inflating: training_set/testing_set/Oblong/oblong (891).jpg
#   inflating: training_set/testing_set/Oblong/oblong (892).jpg
#   inflating: training_set/testing_set/Oblong/oblong (893).jpg
#   inflating: training_set/testing_set/Oblong/oblong (894).jpg
#   inflating: training_set/testing_set/Oblong/oblong (895).jpg
#   inflating: training_set/testing_set/Oblong/oblong (896).jpg
#   inflating: training_set/testing_set/Oblong/oblong (897).jpg
#   inflating: training_set/testing_set/Oblong/oblong (898).jpg
#   inflating: training_set/testing_set/Oblong/oblong (899).jpg
#   inflating: training_set/testing_set/Oblong/oblong (9).jpg
#   inflating: training_set/testing_set/Oblong/oblong (900).jpg
#   inflating: training_set/testing_set/Oblong/oblong (901).jpg
#   inflating: training_set/testing_set/Oblong/oblong (905).jpg
#   inflating: training_set/testing_set/Oblong/oblong (906).jpg
#   inflating: training_set/testing_set/Oblong/oblong (907).jpg
#   inflating: training_set/testing_set/Oblong/oblong (908).jpg
#   inflating: training_set/testing_set/Oblong/oblong (909).jpg
#   inflating: training_set/testing_set/Oblong/oblong (910).jpg
#   inflating: training_set/testing_set/Oblong/oblong (911).jpg
#   inflating: training_set/testing_set/Oblong/oblong (912).jpg
#   inflating: training_set/testing_set/Oblong/oblong (913).jpg
#   inflating: training_set/testing_set/Oblong/oblong (914).jpg
#   inflating: training_set/testing_set/Oblong/oblong (915).jpg
#   inflating: training_set/testing_set/Oblong/oblong (916).jpg
#   inflating: training_set/testing_set/Oblong/oblong (917).jpg
#   inflating: training_set/testing_set/Oblong/oblong (918).jpg
#   inflating: training_set/testing_set/Oblong/oblong (919).jpg
#   inflating: training_set/testing_set/Oblong/oblong (920).jpg
#   inflating: training_set/testing_set/Oblong/oblong (921).jpg
#   inflating: training_set/testing_set/Oblong/oblong (922).jpg
#   inflating: training_set/testing_set/Oblong/oblong (923).jpg
#   inflating: training_set/testing_set/Oblong/oblong (925).jpg
#   inflating: training_set/testing_set/Oblong/oblong (926).jpg
#   inflating: training_set/testing_set/Oblong/oblong (929).jpg
#   inflating: training_set/testing_set/Oblong/oblong (955).jpg
#   inflating: training_set/testing_set/Oblong/oblong (964).jpg
#   inflating: training_set/testing_set/Oblong/oblong (97).jpg
#   inflating: training_set/testing_set/Oblong/oblong (981).jpg
#   inflating: training_set/testing_set/Oblong/oblong (987).jpg
#   inflating: training_set/testing_set/Oblong/oblong (990).jpg
#   inflating: training_set/testing_set/Oblong/oblong (994).jpg
#   inflating: training_set/testing_set/Oblong/oblong (996).jpg
#   inflating: training_set/testing_set/Oblong/oblong (997).jpg
#   inflating: training_set/testing_set/Oval/oval (106).jpg
#   inflating: training_set/testing_set/Oval/oval (109).jpg
#   inflating: training_set/testing_set/Oval/oval (140).jpg
#   inflating: training_set/testing_set/Oval/oval (141).jpg
#   inflating: training_set/testing_set/Oval/oval (142).jpg
#   inflating: training_set/testing_set/Oval/oval (143).jpg
#   inflating: training_set/testing_set/Oval/oval (144).jpg
#   inflating: training_set/testing_set/Round/round (749).jpg
#   inflating: training_set/testing_set/Round/round (750).jpg
#   inflating: training_set/testing_set/Round/round (79).jpg
#   inflating: training_set/testing_set/Round/round (8).jpg
#   inflating: training_set/testing_set/Round/round (80).jpg
#   inflating: training_set/testing_set/Round/round (83).jpg
#   inflating: training_set/testing_set/Round/round (84).jpg
#   inflating: training_set/testing_set/Round/round (85).jpg
#   inflating: training_set/testing_set/Round/round (861).jpg
#   inflating: training_set/testing_set/Round/round (862).jpg
#   inflating: training_set/testing_set/Round/round (87).jpg
#   inflating: training_set/testing_set/Round/round (88).jpg
#   inflating: training_set/testing_set/Round/round (889).jpg
#   inflating: training_set/testing_set/Round/round (89).jpg
#   inflating: training_set/testing_set/Round/round (890).jpg
#   inflating: training_set/testing_set/Round/round (891).jpg
#   inflating: training_set/testing_set/Round/round (892).jpg
#   inflating: training_set/testing_set/Round/round (894).jpg
#   inflating: training_set/testing_set/Round/round (895).jpg
#   inflating: training_set/testing_set/Round/round (896).jpg
#   inflating: training_set/testing_set/Round/round (897).jpg
#   inflating: training_set/testing_set/Round/round (898).jpg
#   inflating: training_set/testing_set/Round/round (899).jpg
#   inflating: training_set/testing_set/Round/round (90).jpg
# ...
#   inflating: training_set/training_set/Square/square (747).jpg
#   inflating: training_set/training_set/Square/square (748).jpg
#   inflating: training_set/training_set/Square/square (749).jpg
#   inflating: training_set/training_set/Square/square (75).jpg
#   inflating: training_set/training_set/Square/square (750).jpg
#   inflating: training_set/training_set/Square/square (751).jpg
#   inflating: training_set/training_set/Square/square (752).jpg
#   inflating: training_set/training_set/Square/square (753).jpg
#   inflating: training_set/training_set/Square/square (754).jpg
#   inflating: training_set/training_set/Square/square (755).jpg
#   inflating: training_set/training_set/Square/square (756).jpg
#   inflating: training_set/training_set/Square/square (758).jpg
#   inflating: training_set/training_set/Square/square (759).jpg
#   inflating: training_set/training_set/Square/square (76).jpg
#   inflating: training_set/training_set/Square/square (760).jpg
#   inflating: training_set/training_set/Square/square (761).jpg
#   inflating: training_set/training_set/Square/square (762).jpg
#   inflating: training_set/training_set/Square/square (77).jpg
#   inflating: training_set/training_set/Square/square (775).jpg
#   inflating: training_set/training_set/Square/square (776).jpg
#   inflating: training_set/training_set/Square/square (777).jpg
#   inflating: training_set/training_set/Square/square (778).jpg
#   inflating: training_set/training_set/Square/square (779).jpg
#   inflating: training_set/training_set/Square/square (78).jpg
#   inflating: training_set/training_set/Square/square (780).jpg
#   inflating: training_set/training_set/Square/square (781).jpg
#   inflating: training_set/training_set/Square/square (782).jpg
#   inflating: training_set/training_set/Square/square (783).jpg
#   inflating: training_set/training_set/Square/square (784).jpg
#   inflating: training_set/training_set/Square/square (785).jpg
#   inflating: training_set/training_set/Square/square (786).jpg
#   inflating: training_set/training_set/Square/square (787).jpg
#   inflating: training_set/training_set/Square/square (789).jpg
#   inflating: training_set/training_set/Square/square (79).jpg
#   inflating: training_set/training_set/Square/square (790).jpg
#   inflating: training_set/training_set/Square/square (791).jpg
#   inflating: training_set/training_set/Square/square (792).jpg
#   inflating: training_set/training_set/Square/square (793).jpg
#   inflating: training_set/training_set/Square/square (794).jpg
#   inflating: training_set/training_set/Square/square (795).jpg
#   inflating: training_set/training_set/Square/square (796).jpg
#   inflating: training_set/training_set/Square/square (797).jpg
#   inflating: training_set/training_set/Square/square (798).jpg
#   inflating: training_set/training_set/Square/square (799).jpg
#   inflating: training_set/training_set/Square/square (80).jpg
#   inflating: training_set/training_set/Square/square (800).jpg
#   inflating: training_set/training_set/Square/square (801).jpg
#   inflating: training_set/training_set/Square/square (802).jpg
#   inflating: training_set/training_set/Square/square (803).jpg
#   inflating: training_set/training_set/Square/square (804).jpg
#   inflating: training_set/training_set/Square/square (805).jpg
#   inflating: training_set/training_set/Square/square (806).jpg
#   inflating: training_set/training_set/Square/square (807).jpg
#   inflating: training_set/training_set/Square/square (808).jpg
#   inflating: training_set/training_set/Square/square (809).jpg
#   inflating: training_set/training_set/Square/square (81).jpg
#   inflating: training_set/training_set/Square/square (810).jpg
#   inflating: training_set/training_set/Square/square (811).jpg
#   inflating: training_set/training_set/Square/square (812).jpg
#   inflating: training_set/training_set/Square/square (813).jpg
#   inflating: training_set/training_set/Square/square (814).jpg
#   inflating: training_set/training_set/Square/square (815).jpg
#   inflating: training_set/training_set/Square/square (816).jpg
#   inflating: training_set/training_set/Square/square (817).jpg
#   inflating: training_set/training_set/Square/square (818).jpg
#   inflating: training_set/training_set/Square/square (819).jpg
#   inflating: training_set/training_set/Square/square (82).jpg
#   inflating: training_set/training_set/Square/square (820).jpg
#   inflating: training_set/training_set/Square/square (821).jpg
#   inflating: training_set/training_set/Square/square (822).jpg
#   inflating: training_set/training_set/Square/square (823).jpg
#   inflating: training_set/training_set/Square/square (829).jpg
#   inflating: training_set/training_set/Square/square (83).jpg
#   inflating: training_set/training_set/Square/square (830).jpg
#   inflating: training_set/training_set/Square/square (831).jpg
#   inflating: training_set/training_set/Square/square (832).jpg
#   inflating: training_set/training_set/Square/square (833).jpg
#   inflating: training_set/training_set/Square/square (834).jpg
#   inflating: training_set/training_set/Square/square (835).jpg
#   inflating: training_set/training_set/Square/square (836).jpg
#   inflating: training_set/training_set/Square/square (837).jpg
#   inflating: training_set/training_set/Square/square (838).jpg
#   inflating: training_set/training_set/Square/square (839).jpg
#   inflating: training_set/training_set/Square/square (840).jpg
#   inflating: training_set/training_set/Square/square (841).jpg
#   inflating: training_set/training_set/Square/square (842).jpg
#   inflating: training_set/training_set/Square/square (843).jpg
#   inflating: training_set/training_set/Square/square (844).jpg
#   inflating: training_set/training_set/Square/square (845).jpg
#   inflating: training_set/training_set/Square/square (846).jpg
#   inflating: training_set/training_set/Square/square (847).jpg
#   inflating: training_set/training_set/Square/square (848).jpg
#   inflating: training_set/training_set/Square/square (849).jpg
#   inflating: training_set/training_set/Square/square (85).jpg
#   inflating: training_set/training_set/Square/square (850).jpg
#   inflating: training_set/training_set/Square/square (851).jpg
#   inflating: training_set/training_set/Square/square (852).jpg
#   inflating: training_set/training_set/Square/square (853).jpg
#   inflating: training_set/training_set/Square/square (854).jpg
#   inflating: training_set/training_set/Square/square (855).jpg
#   inflating: training_set/training_set/Square/square (856).jpg
#   inflating: training_set/training_set/Square/square (857).jpg
#   inflating: training_set/training_set/Square/square (858).jpg
#   inflating: training_set/training_set/Square/square (859).jpg
#   inflating: training_set/training_set/Square/square (86).jpg
#   inflating: training_set/training_set/Square/square (860).jpg
#   inflating: training_set/training_set/Square/square (861).jpg
#   inflating: training_set/training_set/Square/square (862).jpg
#   inflating: training_set/training_set/Square/square (863).jpg
#   inflating: training_set/training_set/Square/square (864).jpg
#   inflating: training_set/training_set/Square/square (865).jpg
#   inflating: training_set/training_set/Square/square (866).jpg
#   inflating: training_set/training_set/Square/square (867).jpg
#   inflating: training_set/training_set/Square/square (868).jpg
#   inflating: training_set/training_set/Square/square (869).jpg
#   inflating: training_set/training_set/Square/square (87).jpg
#   inflating: training_set/training_set/Square/square (870).jpg
#   inflating: training_set/training_set/Square/square (871).jpg
#   inflating: training_set/training_set/Square/square (872).jpg
#   inflating: training_set/training_set/Square/square (873).jpg
#   inflating: training_set/training_set/Square/square (874).jpg
#   inflating: training_set/training_set/Square/square (876).jpg
#   inflating: training_set/training_set/Square/square (877).jpg
#   inflating: training_set/training_set/Square/square (878).jpg
#   inflating: training_set/training_set/Square/square (879).jpg
#   inflating: training_set/training_set/Square/square (88).jpg
#   inflating: training_set/training_set/Square/square (880).jpg
#   inflating: training_set/training_set/Square/square (881).jpg
#   inflating: training_set/training_set/Square/square (882).jpg
#   inflating: training_set/training_set/Square/square (883).jpg
#   inflating: training_set/training_set/Square/square (884).jpg
#   inflating: training_set/training_set/Square/square (885).jpg
#   inflating: training_set/training_set/Square/square (886).jpg
#   inflating: training_set/training_set/Square/square (887).jpg
#   inflating: training_set/training_set/Square/square (888).jpg
#   inflating: training_set/training_set/Square/square (889).jpg
#   inflating: training_set/training_set/Square/square (89).jpg
#   inflating: training_set/training_set/Square/square (890).jpg
#   inflating: training_set/training_set/Square/square (891).jpg
#   inflating: training_set/training_set/Square/square (892).jpg
#   inflating: training_set/training_set/Square/square (893).jpg
#   inflating: training_set/training_set/Square/square (894).jpg
#   inflating: training_set/training_set/Square/square (895).jpg
#   inflating: training_set/training_set/Square/square (896).jpg
#   inflating: training_set/training_set/Square/square (897).jpg
#   inflating: training_set/training_set/Square/square (898).jpg
#   inflating: training_set/training_set/Square/square (90).jpg
#   inflating: training_set/training_set/Square/square (900).jpg
#   inflating: training_set/training_set/Square/square (903).jpg
#   inflating: training_set/training_set/Square/square (904).jpg
#   inflating: training_set/training_set/Square/square (905).jpg
#   inflating: training_set/training_set/Square/square (906).jpg
#   inflating: training_set/training_set/Square/square (907).jpg
#   inflating: training_set/training_set/Square/square (908).jpg
#   inflating: training_set/training_set/Square/square (909).jpg
#   inflating: training_set/training_set/Square/square (91).jpg
#   inflating: training_set/training_set/Square/square (910).jpg
#   inflating: training_set/training_set/Square/square (911).jpg
#   inflating: training_set/training_set/Square/square (912).jpg
#   inflating: training_set/training_set/Square/square (913).jpg
#   inflating: training_set/training_set/Square/square (914).jpg
#   inflating: training_set/training_set/Square/square (915).jpg
#   inflating: training_set/training_set/Square/square (916).jpg
#   inflating: training_set/training_set/Square/square (917).jpg
#   inflating: training_set/training_set/Square/square (918).jpg
#   inflating: training_set/training_set/Square/square (919).jpg
#   inflating: training_set/training_set/Square/square (92).jpg
#   inflating: training_set/training_set/Square/square (920).jpg
#   inflating: training_set/training_set/Square/square (923).jpg
#   inflating: training_set/training_set/Square/square (924).jpg
#   inflating: training_set/training_set/Square/square (926).jpg
#   inflating: training_set/training_set/Square/square (927).jpg
#   inflating: training_set/training_set/Square/square (928).jpg
#   inflating: training_set/training_set/Square/square (929).jpg
#   inflating: training_set/training_set/Square/square (93).jpg
#   inflating: training_set/training_set/Square/square (930).jpg
#   inflating: training_set/training_set/Square/square (931).jpg
#   inflating: training_set/training_set/Square/square (932).jpg
#   inflating: training_set/training_set/Square/square (933).jpg
#   inflating: training_set/training_set/Square/square (935).jpg
#   inflating: training_set/training_set/Square/square (937).jpg
#   inflating: training_set/training_set/Square/square (938).jpg
#   inflating: training_set/training_set/Square/square (939).jpg
#   inflating: training_set/training_set/Square/square (94).jpg
#   inflating: training_set/training_set/Square/square (941).jpg
#   inflating: training_set/training_set/Square/square (942).jpg
#   inflating: training_set/training_set/Square/square (943).jpg
#   inflating: training_set/training_set/Square/square (944).jpg
#   inflating: training_set/training_set/Square/square (945).jpg
#   inflating: training_set/training_set/Square/square (946).jpg
#   inflating: training_set/training_set/Square/square (947).jpg
#   inflating: training_set/training_set/Square/square (948).jpg
#   inflating: training_set/training_set/Square/square (949).jpg
#   inflating: training_set/training_set/Square/square (95).jpg
#   inflating: training_set/training_set/Square/square (950).jpg
#   inflating: training_set/training_set/Square/square (951).jpg
#   inflating: training_set/training_set/Square/square (952).jpg
#   inflating: training_set/training_set/Square/square (953).jpg
#   inflating: training_set/training_set/Square/square (954).jpg
#   inflating: training_set/training_set/Square/square (955).jpg
#   inflating: training_set/training_set/Square/square (956).jpg
#   inflating: training_set/training_set/Square/square (957).jpg
#   inflating: training_set/training_set/Square/square (958).jpg
#   inflating: training_set/training_set/Square/square (959).jpg
#   inflating: training_set/training_set/Square/square (96).jpg
#   inflating: training_set/training_set/Square/square (960).jpg
#   inflating: training_set/training_set/Square/square (961).jpg
#   inflating: training_set/training_set/Square/square (962).jpg
#   inflating: training_set/training_set/Square/square (963).jpg
#   inflating: training_set/training_set/Square/square (964).jpg
#   inflating: training_set/training_set/Square/square (965).jpg
#   inflating: training_set/training_set/Square/square (966).jpg
#   inflating: training_set/training_set/Square/square (967).jpg
#   inflating: training_set/training_set/Square/square (968).jpg
#   inflating: training_set/training_set/Square/square (969).jpg
#   inflating: training_set/training_set/Square/square (97).jpg
#   inflating: training_set/training_set/Square/square (970).jpg
#   inflating: training_set/training_set/Square/square (971).jpg
#   inflating: training_set/training_set/Square/square (972).jpg
#   inflating: training_set/training_set/Square/square (973).jpg
#   inflating: training_set/training_set/Square/square (975).jpg
#   inflating: training_set/training_set/Square/square (976).jpg
#   inflating: training_set/training_set/Square/square (978).jpg
#   inflating: training_set/training_set/Square/square (979).jpg
#   inflating: training_set/training_set/Square/square (98).jpg
#   inflating: training_set/training_set/Square/square (980).jpg
#   inflating: training_set/training_set/Square/square (981).jpg
#   inflating: training_set/training_set/Square/square (982).jpg
#   inflating: training_set/training_set/Square/square (983).jpg
#   inflating: training_set/training_set/Square/square (984).jpg
#   inflating: training_set/training_set/Square/square (985).jpg
#   inflating: training_set/training_set/Square/square (986).jpg
#   inflating: training_set/training_set/Square/square (987).jpg
#   inflating: training_set/training_set/Square/square (988).jpg
#   inflating: training_set/training_set/Square/square (989).jpg
#   inflating: training_set/training_set/Square/square (99).jpg
#   inflating: training_set/training_set/Square/square (990).jpg
#   inflating: training_set/training_set/Square/square (991).jpg
#   inflating: training_set/training_set/Square/square (992).jpg
#   inflating: training_set/training_set/Square/square (993).jpg
#   inflating: training_set/training_set/Square/square (994).jpg
#   inflating: training_set/training_set/Square/square (995).jpg
#   inflating: training_set/training_set/Square/square (996).jpg
#   inflating: training_set/training_set/Square/square (997).jpg
#   inflating: training_set/training_set/Square/square (998).jpg
#   inflating: training_set/training_set/Square/square (999).jpg

# %%
import numpy as np
from re import sub
import tensorflow as tf
from tensorflow.keras import metrics
import os

import matplotlib.colors as mcolors

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping


from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image


import matplotlib.pyplot as plt
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image_dataset_from_directory


import math
import matplotlib.pyplot as plt
from imutils import face_utils
import dlib
import cv2
import argparse
import math
from PIL import Image
from tqdm import tqdm

import pydot
import pydotplus
import keras

print("Done importing packages!")
# Out:
# Done importing packages!

# %% [markdown]
# ### Code for Handling Corrupted Images

# %%
import glob
import pathlib
from struct import unpack

# # search all files inside a specific folder
# # *.* means file name with any extension
dir_path = 'datasets/FaceShapeDataset/**/*.jpg'
imgList = [file for file in glob.glob(dir_path, recursive=True)]
len(imgList)
# Out:
# 5000

# %%
marker_mapping = {
    0xffd8: "Start of Image",
    0xffe0: "Application Default Header",
    0xffdb: "Quantization Table",
    0xffc0: "Start of Frame",
    0xffc4: "Define Huffman Table",
    0xffda: "Start of Scan",
    0xffd9: "End of Image"
}


class JPEG:
    def __init__(self, image_file):
        with open(image_file, 'rb') as f:
            self.img_data = f.read()
    
    def decode(self):
        data = self.img_data
        while(True):
            marker, = unpack(">H", data[0:2])
            # print(marker_mapping.get(marker))
            if marker == 0xffd8:
                data = data[2:]
            elif marker == 0xffd9:
                return
            elif marker == 0xffda:
                data = data[-2:]
            else:
                lenchunk, = unpack(">H", data[2:4])
                data = data[2+lenchunk:]            
            if len(data)==0:
                break        

# Initializing a list to contain corrupted image paths
bads = []

# For every image in dataset try decoding, if fails it's a corrupted image
for img in tqdm(imgList):
    image = img
    image = JPEG(image)
    try:
        image.decode()   
    except:
        bads.append(img)

print(f"Total Number of Corrupted Images: {len(bads)}")
print(f"Corrupted Images List:- \n{bads}")

# Removing Corrupted Images
for name in bads:
    os.remove(name)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:28<00:00, 175.91it/s]
# Total Number of Corrupted Images: 7
# Corrupted Images List:-
# ['datasets/FaceShapeDataset\\testing_set\\Square\\square (154).jpg', 'datasets/FaceShapeDataset\\training_set\\Heart\\heart (633).jpg', 'datasets/FaceShapeDataset\\training_set\\Oblong\\oblong (745).jpg', 'datasets/FaceShapeDataset\\training_set\\Oblong\\oblong (751).jpg', 'datasets/FaceShapeDataset\\training_set\\Oblong\\oblong (776).jpg', 'datasets/FaceShapeDataset\\training_set\\Square\\square (172).jpg', 'datasets/FaceShapeDataset\\training_set\\Square\\square (84).jpg']

# %% [markdown]
# # Pre-Processing Pipeline
#
# ## 1. Face Alignment

# %%
def get_angle(point_1, point_2):
    '''
    Takes two point coordinates and join them to create a line in order to 
    find out the angle w.r.t X-axis
    
    Input:
    point_1 : Point A
    point_2 : Point B
    
    Returns:
    angle: Angle w.r.t X-axis in degrees
    '''
    
    angle = math.atan2(point_1[1] - point_2[1], point_1[0] - point_2[0])
    
    angle = math.degrees(angle)

    if angle < -90:
        return (180-abs(angle))
    elif angle >=90 or angle == -90:
        return 0
    return angle


def align_face(image, cascadeClassifier):
    '''
    Uses cascade classifier to align the face to be straight 
    instead of being tilted at some angle
    
    Inputs:
    image : Target Image
    cascadeClassifer: Eye Cascade Classifer Model
    
    Returns:
    aligned_image: image with aligned face
    '''
    eyesLoc = cascadeClassifier.detectMultiScale(image.copy(), 
                                                 scaleFactor = 1.2, 
                                                 minNeighbors = 6)
    
    try:
        point_1 = (eyesLoc[0][0], eyesLoc[0][1])
        point_2 = (eyesLoc[1][0], eyesLoc[1][1])
                   
    
        rotationAngle = get_angle(point_1, point_2)
    
        alignedImage = np.asarray(Image.fromarray(image).rotate(rotationAngle))
        
        alignedShape = alignedImage.shape
    except:
        return image
        
    
    return alignedImage

# %% [markdown]
# ## 2. Face Detection & Cropping

# %%
def draw_fancy_box(img, pt1, pt2, color, thickness, r, d):
    '''
    To draw some fancy box around founded faces in stream
    '''
    x1, y1 = pt1
    x2, y2 = pt2

    # Top left
    cv2.line(img, (x1 + r, y1), (x1 + r + d, y1), color, thickness)
    cv2.line(img, (x1, y1 + r), (x1, y1 + r + d), color, thickness)
    cv2.ellipse(img, (x1 + r, y1 + r), (r, r), 180, 0, 90, color, thickness)

    # Top right
    cv2.line(img, (x2 - r, y1), (x2 - r - d, y1), color, thickness)
    cv2.line(img, (x2, y1 + r), (x2, y1 + r + d), color, thickness)
    cv2.ellipse(img, (x2 - r, y1 + r), (r, r), 270, 0, 90, color, thickness)

    # Bottom left
    cv2.line(img, (x1 + r, y2), (x1 + r + d, y2), color, thickness)
    cv2.line(img, (x1, y2 - r), (x1, y2 - r - d), color, thickness)
    cv2.ellipse(img, (x1 + r, y2 - r), (r, r), 90, 0, 90, color, thickness)

    # Bottom right
    cv2.line(img, (x2 - r, y2), (x2 - r - d, y2), color, thickness)
    cv2.line(img, (x2, y2 - r), (x2, y2 - r - d), color, thickness)
    cv2.ellipse(img, (x2 - r, y2 - r), (r, r), 0, 0, 90, color, thickness)
    

def face_detection(image, detector):
    '''
    This face detector is made using the now classic Histogram of Oriented
    Gradients (HOG) feature combined with a linear classifier, an image
    pyramid, and sliding window detection scheme.  This type of object detector
    is fairly general and capable of detecting many types of semi-rigid objects
    in addition to human faces.
    
    This function detects the face using Dlib
    
    Input:
    image: Input Image containing human face
    detector: Dlib Face Detector Model
    
    Returns:
    image: image with bounded box representing the detected face
    
    face_coordinates : Coordinates of the detected face
    '''

    # Converting the image to gray scale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # The 1 in the second argument indicates that we should upsample the image
    # 1 time.  This will make everything bigger and allow us to detect more
    # faces.

    # Get faces from image
    rects = detector(gray, 1)
    
    face_cordinates = []
    # For each detected face, draw boxes.
    for (i, rect) in enumerate(rects):
        # Finding points for rectangle to draw on face
        x1, y1, x2, y2, w, h = rect.left(), rect.top(), rect.right() + \
            1, rect.bottom() + 1, rect.width(), rect.height()
    
        face_cordinates.append((math.floor(x1*0.8), math.floor(y1*0.60), math.ceil(h*1.40), math.ceil(h*1.40)))

        draw_fancy_box(image, (x1, y1), (x2, y2), (0, 0, 255), 2, 10, 20)

    return image, face_cordinates



def faceDetectAndCrop(image, detector):
    '''
    This function will use Face Detection to face and crop the image contain only face
    
    Input:
    image: Target image to be cropped
    detector: Dlib Face Detector Model
    
    Returns:
    cropped_face: a cropped image containing mostly the face
    '''
    face_coordinates = face_detection(image.copy(), detector)[1]
    
    # If face not detected return image as it is
    if len(face_coordinates) == 0:
        return image
    cropped_face = None
    
    maxArea = 0
    largestFaceIndex = 0
    # Choose the face which is largest
    for i, coordinates in enumerate(face_coordinates):
        (x1, y1, w, h) = coordinates
        
        # Calculating area
        area = w * h
        if area > maxArea:
            maxArea = area
            largestFaceIndex = i
        
    (x1, y1, w, h) = face_coordinates[largestFaceIndex]
    cropped_face = image.copy()[y1:y1 + h, x1:x1 + w]
    
    try:
        cropped_shape = cropped_face.shape
    except:
        return image
    
    if cropped_shape[1]==0:
        return image
    
    return cropped_face

# %%
def preprocessImage(image):
    '''
    This function preprocesses the image for Face Shape Detection Models
    It contains following steps of Pre-Processing:
    1. Face Alignment
    2. Face Detection and Cropping
    3. Grayscaling
    4. Image Resizing to 128x128
    
    Inputs:
    image: Image to be preprocessed
    
    Returns:
    resized: Preprocessed image
    '''
    # Aligning Face 
    alignedFace = align_face(image, eye_cascade)
    
    # Detecting and Cropping Face Area
    croppedFace = faceDetectAndCrop(alignedFace,face_detector)
    
    # Converting Image to GrayScale
    grayscaled = cv2.cvtColor(croppedFace, cv2.COLOR_BGR2GRAY)
    
    # Resizing Image
    resized = cv2.resize(grayscaled, (128, 128))
               
    return resized

# %%
# Loading Models for Pre-Processing
eye_cascade = cv2.CascadeClassifier('face_alignment\haarcascade_eye.xml')
face_detector = dlib.get_frontal_face_detector()

# %% [markdown]
# ### Code for Pre-Processing all the Images in the dataset

# %%
# Specifying Source Dataset Directory
rootdir = "datasets\FaceShapeDataset\\"

# Destination where preprocessed dataset will be wrote
preprocessedRoot = "preprocessed"

# Create destination directory if not exists
if not os.path.exists(preprocessedRoot):
    os.mkdir(preprocessedRoot)

# Walk through all the directory, subdirectories and files for Source directory
for subdir, dirs, files in tqdm(os.walk(rootdir)):
    
    # Resolve current sub-directory name
    subDirectoryName = "\\".join(subdir.split("\\")[1:])
    
    # Specifying output folder based on subdirectory name
    outputFolder = os.path.join(preprocessedRoot, subDirectoryName)
    
    # Creating output subdirectory
    if subDirectoryName!='' and not os.path.exists(outputFolder):
        os.mkdir(outputFolder)
        
    # For every image files
    for file in files:
        # Ignoring Desktop.ini if exists
        if file=='desktop.ini':
            continue
        
        # Defining Input/Output path
        inputPath = os.path.join(subdir, file)
        outputPath = os.path.join(outputFolder, file)
        
        if os.path.exists(outputPath):
            continue
        
        # Reading the image
        image = cv2.imread(inputPath)
        
        try:
            img_shape = image.shape
        except:
            continue
        
        # Preprocessing the image
        preprocessedImage = preprocessImage(image)

        try:
            # Writing to destination
            cv2.imwrite(outputPath, preprocessedImage)
        except:
            # If failed, printing path
            print(inputPath)

# %% [markdown]
# # Model Building & Training

# %%
BATCH_SIZE = 96
IMG_SIZE = (128, 128)

# Defining Dataset Directory Path
data_dir = "datasets/preprocessed/FaceShapeDataset/"

train_dataset = image_dataset_from_directory(data_dir+"training_set",
                                             shuffle=True,
                                             label_mode = 'categorical',
                                             batch_size=BATCH_SIZE,
                                             seed = 42,
                                             image_size=IMG_SIZE)

validation_dataset = image_dataset_from_directory(data_dir+"testing_set",
                                             shuffle=True,
                                             label_mode = 'categorical',
                                             batch_size=BATCH_SIZE,
                                             seed = 42,
                                             image_size=IMG_SIZE)
# Out:
# Found 3993 files belonging to 5 classes.
# Found 999 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names
num_classes = len(class_names)

for i in range(1, num_classes + 1):
    print(str(i) + ". ", class_names[i - 1])
# Out:
# 1.  Heart
# 2.  Oblong
# 3.  Oval
# 4.  Round
# 5.  Square

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 9
# Number of test batches: 2

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
# add more augmentations
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
METRICS = [
      metrics.CategoricalAccuracy(name='accuracy'),
      metrics.Precision(name='precision'),
      metrics.Recall(name='recall')
]

# %%
IMG_SHAPE = IMG_SIZE + (3,)

base_model = tf.keras.applications.efficientnet_v2.EfficientNetV2M(
                                include_top=False,
                                weights="imagenet",
                                input_shape=IMG_SHAPE,
                                include_preprocessing=False
                            )

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# 2022-08-20 11:03:56.488669: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8204
# 2022-08-20 11:03:57.250895: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-08-20 11:03:57.251619: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-08-20 11:03:57.251667: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-08-20 11:03:57.252376: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-08-20 11:03:57.252499: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# (96, 4, 4, 1280)

# %%
base_model.trainable = True

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)

print(feature_batch_average.shape)
# Out:
# (96, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(num_classes, activation="softmax")
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (96, 5)

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = data_augmentation(inputs)
x = base_model(x, training=True)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
# Initializing model output directory name
modelNameDirectory = 'FaceDetectionModel'

# Creating model directory if doest not exists
if not os.path.exists(modelNameDirectory):
    os.mkdir(modelNameDirectory)

# Defining model file name
filePath = modelNameDirectory + '/' + 'EfficientNetV2-M'+ '_BestModel.h5'

# Defining model checkpoint for saving best model
bestModelCheckpoint = ModelCheckpoint(filePath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

# Defining decaying learning rate callback
decayLR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=3)

# Defining early stopping callback
earlystopCheckpoint = EarlyStopping(monitor="val_loss", min_delta=0, patience=9, verbose=1)

# Preparing list of all callbacks
callbacksList = [bestModelCheckpoint, decayLR, earlystopCheckpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=METRICS
              )
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 4, 4, 1280)       53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense (Dense)               (None, 5)                 6405
#
# =================================================================
# Total params: 53,156,793
# Trainable params: 52,864,761
# Non-trainable params: 292,032
# _________________________________________________________________

# %%
initial_epochs = 100

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset,
                    callbacks = callbacksList
                    )
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# 42/42 [==============================] - ETA: 0s - loss: 1.3084 - accuracy: 0.4400 - precision: 0.6282 - recall: 0.2467
# Epoch 1: val_loss improved from inf to 1.04859, saving model to FaceDetectionModel/EfficientNetV2-M_BestModel.h5
# 42/42 [==============================] - 119s 2s/step - loss: 1.3084 - accuracy: 0.4400 - precision: 0.6282 - recall: 0.2467 - val_loss: 1.0486 - val_accuracy: 0.5898 - val_precision: 0.7563 - val_recall: 0.3730 - lr: 0.0010
# Epoch 2/100
# 42/42 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.6572 - precision: 0.7719 - recall: 0.5322
# Epoch 2: val_loss improved from 1.04859 to 0.86999, saving model to FaceDetectionModel/EfficientNetV2-M_BestModel.h5
# 42/42 [==============================] - 71s 2s/step - loss: 0.8939 - accuracy: 0.6572 - precision: 0.7719 - recall: 0.5322 - val_loss: 0.8700 - val_accuracy: 0.6654 - val_precision: 0.7376 - val_recall: 0.6097 - lr: 0.0010
# Epoch 3/100
# 42/42 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.7608 - precision: 0.8267 - recall: 0.6967
# Epoch 3: val_loss did not improve from 0.86999
# 42/42 [==============================] - 65s 2s/step - loss: 0.6376 - accuracy: 0.7608 - precision: 0.8267 - recall: 0.6967 - val_loss: 0.9359 - val_accuracy: 0.6778 - val_precision: 0.7255 - val_recall: 0.6320 - lr: 0.0010
# Epoch 4/100
# 42/42 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8127 - precision: 0.8547 - recall: 0.7731
# Epoch 4: val_loss improved from 0.86999 to 0.83112, saving model to FaceDetectionModel/EfficientNetV2-M_BestModel.h5
# 42/42 [==============================] - 72s 2s/step - loss: 0.5098 - accuracy: 0.8127 - precision: 0.8547 - recall: 0.7731 - val_loss: 0.8311 - val_accuracy: 0.7001 - val_precision: 0.7603 - val_recall: 0.6642 - lr: 0.0010
# Epoch 5/100
# 42/42 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8487 - precision: 0.8856 - recall: 0.8144
# Epoch 5: val_loss improved from 0.83112 to 0.82052, saving model to FaceDetectionModel/EfficientNetV2-M_BestModel.h5
# 42/42 [==============================] - 72s 2s/step - loss: 0.4137 - accuracy: 0.8487 - precision: 0.8856 - recall: 0.8144 - val_loss: 0.8205 - val_accuracy: 0.7038 - val_precision: 0.7472 - val_recall: 0.6629 - lr: 0.0010
# Epoch 6/100
# 42/42 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8718 - precision: 0.9005 - recall: 0.8480
# Epoch 6: val_loss did not improve from 0.82052
# 42/42 [==============================] - 65s 2s/step - loss: 0.3561 - accuracy: 0.8718 - precision: 0.9005 - recall: 0.8480 - val_loss: 0.8952 - val_accuracy: 0.7162 - val_precision: 0.7338 - val_recall: 0.6865 - lr: 0.0010
# Epoch 7/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9041 - precision: 0.9194 - recall: 0.8858
# Epoch 7: val_loss did not improve from 0.82052
# 42/42 [==============================] - 66s 2s/step - loss: 0.2812 - accuracy: 0.9041 - precision: 0.9194 - recall: 0.8858 - val_loss: 0.9730 - val_accuracy: 0.7150 - val_precision: 0.7331 - val_recall: 0.6976 - lr: 0.0010
# Epoch 8/100
# 42/42 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9184 - precision: 0.9305 - recall: 0.9088
# Epoch 8: val_loss did not improve from 0.82052
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 42/42 [==============================] - 65s 2s/step - loss: 0.2285 - accuracy: 0.9184 - precision: 0.9305 - recall: 0.9088 - val_loss: 0.9186 - val_accuracy: 0.7398 - val_precision: 0.7561 - val_recall: 0.7336 - lr: 0.0010
# Epoch 9/100
# 42/42 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9639 - precision: 0.9701 - recall: 0.9587
# Epoch 9: val_loss improved from 0.82052 to 0.76629, saving model to FaceDetectionModel/EfficientNetV2-M_BestModel.h5
# 42/42 [==============================] - 72s 2s/step - loss: 0.1098 - accuracy: 0.9639 - precision: 0.9701 - recall: 0.9587 - val_loss: 0.7663 - val_accuracy: 0.7732 - val_precision: 0.7852 - val_recall: 0.7608 - lr: 2.0000e-04
# Epoch 10/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9862 - precision: 0.9872 - recall: 0.9830
# Epoch 10: val_loss did not improve from 0.76629
# 42/42 [==============================] - 65s 2s/step - loss: 0.0497 - accuracy: 0.9862 - precision: 0.9872 - recall: 0.9830 - val_loss: 0.8488 - val_accuracy: 0.7757 - val_precision: 0.7883 - val_recall: 0.7708 - lr: 2.0000e-04
# Epoch 11/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9925 - precision: 0.9930 - recall: 0.9915
# Epoch 11: val_loss did not improve from 0.76629
# 42/42 [==============================] - 65s 2s/step - loss: 0.0236 - accuracy: 0.9925 - precision: 0.9930 - recall: 0.9915 - val_loss: 0.9432 - val_accuracy: 0.7881 - val_precision: 0.7957 - val_recall: 0.7819 - lr: 2.0000e-04
# Epoch 12/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9925 - precision: 0.9932 - recall: 0.9917
# Epoch 12: val_loss did not improve from 0.76629
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 42/42 [==============================] - 65s 2s/step - loss: 0.0262 - accuracy: 0.9925 - precision: 0.9932 - recall: 0.9917 - val_loss: 0.9848 - val_accuracy: 0.7831 - val_precision: 0.7964 - val_recall: 0.7757 - lr: 2.0000e-04
# Epoch 13/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9950 - precision: 0.9955 - recall: 0.9942
# Epoch 13: val_loss did not improve from 0.76629
# 42/42 [==============================] - 64s 2s/step - loss: 0.0157 - accuracy: 0.9950 - precision: 0.9955 - recall: 0.9942 - val_loss: 0.8907 - val_accuracy: 0.8042 - val_precision: 0.8144 - val_recall: 0.7993 - lr: 4.0000e-05
# Epoch 14/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9970 - precision: 0.9972 - recall: 0.9967
# Epoch 14: val_loss did not improve from 0.76629
# 42/42 [==============================] - 65s 2s/step - loss: 0.0128 - accuracy: 0.9970 - precision: 0.9972 - recall: 0.9967 - val_loss: 0.9475 - val_accuracy: 0.7906 - val_precision: 0.7962 - val_recall: 0.7844 - lr: 4.0000e-05
# Epoch 15/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9975 - precision: 0.9975 - recall: 0.9975
# Epoch 15: val_loss did not improve from 0.76629
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 42/42 [==============================] - 65s 2s/step - loss: 0.0113 - accuracy: 0.9975 - precision: 0.9975 - recall: 0.9975 - val_loss: 0.9548 - val_accuracy: 0.7807 - val_precision: 0.7872 - val_recall: 0.7745 - lr: 4.0000e-05
# Epoch 16/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9975 - precision: 0.9975 - recall: 0.9972
# Epoch 16: val_loss did not improve from 0.76629
# 42/42 [==============================] - 65s 2s/step - loss: 0.0087 - accuracy: 0.9975 - precision: 0.9975 - recall: 0.9972 - val_loss: 1.0075 - val_accuracy: 0.7819 - val_precision: 0.7859 - val_recall: 0.7732 - lr: 8.0000e-06
# Epoch 17/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9967
# Epoch 17: val_loss did not improve from 0.76629
# 42/42 [==============================] - 65s 2s/step - loss: 0.0107 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9967 - val_loss: 0.9448 - val_accuracy: 0.7906 - val_precision: 0.7987 - val_recall: 0.7869 - lr: 8.0000e-06
# Epoch 18/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962
# Epoch 18: val_loss did not improve from 0.76629
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 42/42 [==============================] - 65s 2s/step - loss: 0.0103 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.9445 - val_accuracy: 0.7931 - val_precision: 0.8020 - val_recall: 0.7881 - lr: 8.0000e-06
# Epoch 18: early stopping

# %%
# Defining plot function for plotting Graph between Training and Validation loss as well as accuracy
def plot(x):
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
  axes[0].plot(x.history['loss'])   
  axes[0].plot(x.history['val_loss'])
  axes[0].legend(['Training Loss','Validation Loss'])

  axes[1].plot(x.history['accuracy'])   
  axes[1].plot(x.history['val_accuracy'])
  axes[1].legend(['Training Accuracy','Validation Accuracy'])

# %%
plot(history)

# %% [markdown]
# # Model Prediction on Test Dataset

# %%
# Loading FaceShapeDetecor EfficientNetV2-M Model
FSD_EfficientNetV2_M = tf.keras.models.load_model("FaceDetectionModel/EfficientNetV2-M_BestModel.h5")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2

# %%
# Plotting Model Architecture
keras.utils.vis_utils.pydot = pydotplus
tf.keras.utils.plot_model(FSD_EfficientNetV2_M, to_file='FSD_EfficientNetV2_M.png', show_shapes=True)

# %%
# %%time
# Evaluating FaceShapeDetecor EfficientNetV2-M Model
FSD_EfficientNetV2_M.evaluate(test_dataset)
# Out:
# 2/2 [==============================] - 3s 179ms/step - loss: 0.7871 - accuracy: 0.8177 - precision: 0.8289 - recall: 0.8073
# Wall time: 2.69 s
# [0.787131130695343, 0.8177083134651184, 0.8288770318031311, 0.8072916865348816]

# %% [markdown]
# # Prediction Pipeline

# %%
# Reading a Single Original Image
image = cv2.imread("datasets/FaceShapeDataset/testing_set/Oblong/oblong (926).jpg")

# %%
# %%time

# Preprocessing Image
preprocessedImage = cv2.cvtColor(preprocessImage(image), cv2.COLOR_BGR2RGB)

# Reshaping Image to feed into model
reshapedImage = preprocessedImage.reshape((1,128,128,3))

# Predicting
FSD_EfficientNetV2_M.predict(reshapedImage)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# Wall time: 498 ms
# array([[0.20677584, 0.17999616, 0.31356925, 0.16484565, 0.1348131 ]],
#       dtype=float32)
